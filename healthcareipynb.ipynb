# %% [markdown]
# <a href="https://colab.research.google.com/github/shanthinidevis-star/DAY-2-FDP/blob/main/healthcareipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
data = pd.read_csv("healthcare.csv")

# Display first 5 rows
print(data.head())

# Check missing values
print(data.isnull().sum())

# Visualize age distribution
plt.figure(figsize=(8,5))
sns.histplot(data['Age'], bins=20)
plt.title("Age Distribution of Patients")
plt.show()

# Disease count
plt.figure(figsize=(8,5))
sns.countplot(x='Disease', data=data)
plt.title("Disease Distribution")
plt.xticks(rotation=45)
plt.show()
# Out:
#    Patient_ID  Age  Gender  Blood_Pressure  Cholesterol   BMI Diabetes  \
# 0           1   45    Male             130          220  28.5      Yes
# 1           2   34  Female             120          180  24.2       No
# 2           3   60    Male             145          250  31.8      Yes
# 3           4   29  Female             110          170  22.1       No
# 4           5   52    Male             140          240  30.5      Yes
#
#   Heart_Disease
# 0            No
# 1            No
# 2           Yes
# 3            No
# 4           Yes
# Patient_ID        0
# Age               0
# Gender            0
# Blood_Pressure    0
# Cholesterol       0
# BMI               0
# Diabetes          0
# Heart_Disease     0
# dtype: int64
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_2690/3237678530.py in <cell line: 0>()
#      20 # Disease count
# ...
